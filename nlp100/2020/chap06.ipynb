# %%
from pathlib import Path
import os
from zipfile import ZipFile
import pandas as pd

# %%
def load_data():
    raw_zipfile_path = Path(os.getcwd()) / "data" / "news_aggregator.zip"
    raw_zipfile = ZipFile(raw_zipfile_path, metadata_encoding="utf-8")
    with raw_zipfile:
        with raw_zipfile.open("newsCorpora.csv") as news_corpora:
            df = pd.read_csv(
                news_corpora,
                sep="\t",
                header=None,
                names=[
                    "ID",
                    "TITLE",
                    "URL",
                    "PUBLISHER",
                    "CATEGORY",
                    "STORY",
                    "HOSTNAME",
                    "TIMESTAMP",
                ],
            )
            return df


df = load_data()
df
# Out:
#             ID  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 422414  422933
# 422415  422934
# 422416  422935
# 422417  422936
# 422418  422937
#
#                                                                                  TITLE  \
# 0                 Fed official says weak data caused by weather, should not slow taper
# 1                   Fed's Charles Plosser sees high bar for change in pace of tapering
# 2                US open: Stocks fall after Fed official hints at accelerated tapering
# 3                           Fed risks falling 'behind the curve', Charles Plosser says
# 4                                   Fed's Plosser: Nasty Weather Has Curbed Job Growth
# ...                                                                                ...
# 422414      Surgeons to remove 4-year-old's rib to rebuild damaged throat - CBS 3  ...
# 422415             Boy to have surgery on esophagus after battery burns hole in throat
# 422416   Child who swallowed battery to have reconstructive surgery at Cincinnati  ...
# 422417      Phoenix boy undergoes surgery to repair throat damage - WFSB 3 Connecticut
# 422418  Phoenix boy undergoes surgery to repair throat damage - CBS 3 Springfield  ...
#
#                                                                                                         URL  \
# 0       http://www.latimes.com/business/money/la-fi-mo-federal-reserve-plosser-stimulus-economy-20140310...
# 1       http://www.livemint.com/Politics/H2EvwJSK2VE6OF7iK1g3PP/Feds-Charles-Plosser-sees-high-bar-for-c...
# 2       http://www.ifamagazine.com/news/us-open-stocks-fall-after-fed-official-hints-at-accelerated-tape...
# 3            http://www.ifamagazine.com/news/fed-risks-falling-behind-the-curve-charles-plosser-says-294430
# 4       http://www.moneynews.com/Economy/federal-reserve-charles-plosser-weather-job-growth/2014/03/10/i...
# ...                                                                                                     ...
# 422414  http://www.cbs3springfield.com/story/26378648/surgeons-removed-4-year-olds-rib-to-rebuild-his-da...
# 422415  http://www.wlwt.com/news/boy-to-have-surgery-on-esophagus-after-battery-burns-hole-in-throat/277...
# 422416  http://www.newsnet5.com/news/local-news/child-who-swallowed-battery-to-have-reconstructive-surge...
# 422417  http://www.wfsb.com/story/26368078/phoenix-boy-undergoes-surgery-to-repair-throat-damage-from-bu...
# 422418  http://www.cbs3springfield.com/story/26368078/phoenix-boy-undergoes-surgery-to-repair-throat-dam...
#
#                 PUBLISHER CATEGORY                          STORY  \
# 0       Los Angeles Times        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 1                Livemint        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 2            IFA Magazine        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 3            IFA Magazine        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 4               Moneynews        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# ...                   ...      ...                            ...
# 422414            WSHM-TV        m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422415    WLWT Cincinnati        m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422416       NewsNet5.com        m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422417               WFSB        m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
# 422418            WSHM-TV        m  dpcLMoJD69UYMXMxaoEFnWql9YjQM
#
#                        HOSTNAME      TIMESTAMP
# 0               www.latimes.com  1394470370698
# 1              www.livemint.com  1394470371207
# 2           www.ifamagazine.com  1394470371550
# 3           www.ifamagazine.com  1394470371793
# 4             www.moneynews.com  1394470372027
# ...                         ...            ...
# 422414  www.cbs3springfield.com  1409229190251
# 422415             www.wlwt.com  1409229190508
# 422416         www.newsnet5.com  1409229190771
# 422417             www.wfsb.com  1409229191071
# 422418  www.cbs3springfield.com  1409229191565
#
# [422419 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

def p50():
    selected_publishers = set(["Reuters", "Huffington Post", "Businessweek", "Contactmusic.com", "Daily Mail"])
    selected_articles = df[df["PUBLISHER"].isin(selected_publishers)]
    selected_articles_with_shuffled = selected_articles.sample(frac=1)
    assert len(selected_articles_with_shuffled) == 13340
    # https://stackabuse.com/scikit-learns-traintestsplit-training-testing-and-validation-sets/
    train_ratio = 0.8
    test_ratio = 0.1
    validation_ratio = 0.1
    X_train, X_test = train_test_split(selected_articles_with_shuffled, test_size=test_ratio)
    X_train, X_validate = train_test_split(X_train, test_size=validation_ratio/(train_ratio+test_ratio))
    X_train: pd.DataFrame
    X_validate: pd.DataFrame
    X_test: pd.DataFrame
    assert X_train.shape == (10672, 8)
    assert X_validate.shape == (1334, 8)
    assert X_test.shape == (1334, 8)
    output_dir = Path(os.getcwd()) / "data"
    def dump(selected: pd.DataFrame, output_filename: str):
        selected.loc[:,["CATEGORY","TITLE"]].to_csv(output_dir / output_filename, sep="\t", index=None, header=None)
    dump(X_train, "train.txt")
    dump(X_validate, "valid.txt")
    dump(X_test, "test.txt")


p50()
